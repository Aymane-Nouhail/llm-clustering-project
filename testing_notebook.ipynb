# %%
path = "datasets/reverb45k_change/reverb45k_valid"

# %%
import json

with open(path, "r", encoding="utf-8") as f:
    data = [json.loads(line) for line in f if line.strip()]

# %%
from typing import List, Tuple

def load_reverb45k(path: str = "reverb45k.json") -> Tuple[List[str], List[int], List[str]]:
    import json

    print("Loading ReVerb45k dataset...")
    with open(path, "r", encoding="utf-8") as f:
        data = [json.loads(line) for line in f if line.strip()]

    documents = []
    labels = []
    label_mapping = {}
    current_label_id = 0

    # Step 1: Collect all the labels
    for entry in data:
        triple = entry.get("triple", [])
        sentence = " ".join(triple).strip()
        if not sentence:
            continue

        wiki_object = entry.get("entity_linking", {}).get("object", "")
        if not wiki_object:
            continue

        if wiki_object not in label_mapping:
            label_mapping[wiki_object] = current_label_id
            current_label_id += 1

        label = label_mapping[wiki_object]
        documents.append(sentence)
        labels.append(label)

    # Step 2: Filter out single occurrence labels (clusters with only one item)
    label_counts = Counter(labels)
    filtered_docs = [doc for doc, lbl in zip(documents, labels) if label_counts[lbl] > 1]
    filtered_labels = [lbl for lbl in labels if label_counts[lbl] > 1]

    print(f"Loaded {len(filtered_docs)} triples from ReVerb45k after filtering out singleton clusters.")
    print(f"Found {len(set(filtered_labels))} unique object entities (clusters): "
          f"{list(set(filtered_labels))[:10] + ['...'] if len(set(filtered_labels)) > 10 else list(set(filtered_labels))}")

    return filtered_docs, filtered_labels, filtered_docs

# %%
raw_data, labels_list, documents = load_reverb45k(path)
# Out:
# Loading ReVerb45k dataset...
# Loaded 4149 triples from ReVerb45k after filtering out singleton clusters.
# Found 845 unique object entities (clusters): [2049, 2, 4, 6, 2059, 12, 13, 2060, 16, 17, '...']

# %%
labels = labels_list
from collections import Counter

label_counts = Counter(labels)
filtered_docs = [doc for doc, lbl in zip(documents, labels) if label_counts[lbl] > 1]
filtered_labels = [lbl for lbl in labels if label_counts[lbl] > 1]

# %%
len(set(filtered_labels))
# Out:
# 845

# %%
import pandas as pd

df = pd.read_csv("clustering_metrics_results.csv")

# %%
df[df["Dataset"]=="bank77"]
# Out:
#    Dataset                              Method   Status  Accuracy  Precision  \
# 11  bank77                      LLM Correction  Success  0.628571   0.637119
# 12  bank77                      LLM Correction  Success  0.628571   0.637007
# 42  bank77                        Naive KMeans  Success  0.627597   0.635778
# 43  bank77                      LLM Correction  Success  0.628896   0.637371
# 44  bank77  Keyphrase Expansion - concatenated  Success  0.656818   0.656450
# 45  bank77       Keyphrase Expansion - average  Success  0.613961   0.597374
# 46  bank77  Keyphrase Expansion - weighted_0.1  Success  0.638961   0.652810
# 47  bank77  Keyphrase Expansion - weighted_0.2  Success  0.625325   0.612491
# 48  bank77  Keyphrase Expansion - weighted_0.3  Success  0.653571   0.648261
# 49  bank77  Keyphrase Expansion - weighted_0.4  Success  0.620455   0.622782
# 50  bank77  Keyphrase Expansion - weighted_0.5  Success  0.613961   0.597374
# 51  bank77  Keyphrase Expansion - weighted_0.6  Success  0.669156   0.694527
# 52  bank77  Keyphrase Expansion - weighted_0.7  Success  0.627273   0.632833
# 53  bank77  Keyphrase Expansion - weighted_0.8  Success  0.628571   0.638224
# 54  bank77  Keyphrase Expansion - weighted_0.9  Success  0.640909   0.649552
# 55  bank77  Keyphrase Expansion - weighted_1.0  Success  0.665909   0.671204
#
#       Recall  Macro_F1  Micro_F1       NMI       ARI  pairwise_precision  \
# 11  0.628571  0.606680  0.628571  0.810173  0.529171                 NaN
# 12  0.628571  0.606594  0.628571  0.810213  0.529106                 NaN
# 42  0.627597  0.605919  0.627597  0.809713  0.528287                 NaN
# 43  0.628896  0.607003  0.628896  0.810268  0.529282                 NaN
# 44  0.656818  0.632364  0.656818  0.834722  0.566615                 NaN
# 45  0.613961  0.583212  0.613961  0.819189  0.531569                 NaN
# 46  0.638961  0.615033  0.638961  0.822455  0.545906                 NaN
# 47  0.625325  0.592283  0.625325  0.824682  0.550801                 NaN
# 48  0.653571  0.631797  0.653571  0.829342  0.560577                 NaN
# 49  0.620455  0.592704  0.620455  0.825809  0.533389                 NaN
# 50  0.613961  0.583212  0.613961  0.819189  0.531569                 NaN
# 51  0.669156  0.654281  0.669156  0.832373  0.561687                 NaN
# 52  0.627273  0.606297  0.627273  0.822043  0.536809                 NaN
# 53  0.628571  0.611356  0.628571  0.820145  0.542847                 NaN
# 54  0.640909  0.624165  0.640909  0.816848  0.543900                 NaN
# 55  0.665909  0.650043  0.665909  0.827692  0.573048                 NaN
#
#     pairwise_recall  pairwise_f1
# 11              NaN          NaN
# 12              NaN          NaN
# 42              NaN          NaN
# 43              NaN          NaN
# 44              NaN          NaN
# 45              NaN          NaN
# 46              NaN          NaN
# 47              NaN          NaN
# 48              NaN          NaN
# 49              NaN          NaN
# 50              NaN          NaN
# 51              NaN          NaN
# 52              NaN          NaN
# 53              NaN          NaN
# 54              NaN          NaN
# 55              NaN          NaN

# %%
df
